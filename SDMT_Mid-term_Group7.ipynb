# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler 

books_demo = pd.read_csv('SDMT_Midterm_Dataset/books.csv')
books_demo.reset_index(drop = True, inplace = True) 
#books_demo.style.hide_index()
#books_demo.style.hide_index()
#Styler.hide(axis='index')
books_demo
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books_demo.info
# Out:
# <bound method DataFrame.info of          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books_demo.describe()
# Out:
#                 id       book_id  best_book_id       work_id   books_count  \
# count  10000.00000  1.000000e+04  1.000000e+04  1.000000e+04  10000.000000
# mean    5000.50000  5.264697e+06  5.471214e+06  8.646183e+06     75.712700
# std     2886.89568  7.575462e+06  7.827330e+06  1.175106e+07    170.470728
# min        1.00000  1.000000e+00  1.000000e+00  8.700000e+01      1.000000
# 25%     2500.75000  4.627575e+04  4.791175e+04  1.008841e+06     23.000000
# 50%     5000.50000  3.949655e+05  4.251235e+05  2.719524e+06     40.000000
# 75%     7500.25000  9.382225e+06  9.636112e+06  1.451775e+07     67.000000
# max    10000.00000  3.328864e+07  3.553423e+07  5.639960e+07   3455.000000
#
#              isbn13  original_publication_year  average_rating  ratings_count  \
# count  9.415000e+03                9979.000000    10000.000000   1.000000e+04
# mean   9.755044e+12                1981.987674        4.002191   5.400124e+04
# ...

# %%
books_demo.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
books_demo.shape
# Out:
# (10000, 23)

# %%
books_demo.duplicated().sum()
# Out:
# 0

# %%
books_demo['book_id'].duplicated().sum()
# Out:
# 0

# %%
ratings_demo = pd.read_csv('SDMT_Midterm_Dataset/ratings.csv')
ratings_demo
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]

# %%
ratings_demo.info
# Out:
# <bound method DataFrame.info of         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]>

# %%
ratings_demo.describe
# Out:
# <bound method NDFrame.describe of         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]>

# %%
ratings_demo.columns
# Out:
# Index(['book_id', 'user_id', 'rating'], dtype='object')

# %%
ratings_demo.shape
# Out:
# (981756, 3)

# %%
ratings_demo.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 981751    False
# 981752    False
# 981753    False
# 981754    False
# 981755    False
# Length: 981756, dtype: bool

# %%
ratings_demo.duplicated().sum()
# Out:
# 1644

# %%
ratings_demo['book_id'].duplicated()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 981751     True
# 981752     True
# 981753     True
# 981754     True
# 981755     True
# Name: book_id, Length: 981756, dtype: bool

# %%
df_ratings_demo = ratings_demo.groupby(['book_id','user_id']).mean()
df_ratings_demo
# Out:
#                  rating
# book_id user_id
# 1       314         5.0
#         439         3.0
#         588         5.0
#         1169        4.0
#         1185        4.0
# ...                 ...
# 10000   48386       5.0
#         49007       4.0
#         49383       5.0
#         50124       5.0
#         51328       1.0
#
# [979478 rows x 1 columns]

# %%
df_ratings_demo = ratings_demo.groupby(['book_id','user_id']).size()
df_ratings_demo
# Out:
# book_id  user_id
# 1        314        1
#          439        1
#          588        1
#          1169       1
#          1185       1
#                    ..
# 10000    48386      1
#          49007      1
#          49383      1
#          50124      1
#          51328      1
# Length: 979478, dtype: int64
